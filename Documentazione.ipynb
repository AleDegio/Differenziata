# %% [markdown]
# <H1>Documentazione</H1>
# Intelligenza artificiale progettata per smistare la spazzatura.
#
# Link del Github: https://github.com/AleDegio/Differenziata
#
# **Chi siamo?**
# - Luca Armando
# - Alessia De Giovannini
# - Irene Gabutti
# - Matteo Giusti
# - Karni Singh Shekhawat
#
# **Componenti Software:**
# - Tinkercad (https://www.tinkercad.com/things/a94r3y9Ul5M-differenziata/edit)
# - File in Python
# - Teachable Machine
#
# **Componenti Hardware:**
# - Raspberry pi
# - Telecamera del raspberry pi
# - Speaker
#
# **Procedimento:**
#
# Abbiamo preso le immagini da un DB.
# Link del DB: https://storage.googleapis.com/kaggle-data-sets/1115942/1874598/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20210511%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210511T171518Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...
#
# Teachable Machine è uno strumento basato sul Web attraveso il quale puoi creare modelli di machine learning per siti, app e altro ancora, senza esperienza o codice richiesto.
# ![immagine-2.png](attachment:immagine-2.png)
#
# Abbiamo utilizzato una rete neurale a 3 livelli e un Algoritmo di machine learning supervisionato perchè conoscevamo già gli output.
# ![immagine-6.png](attachment:immagine-6.png)
#
# Abbiamo modificato il codice e aggiunto una sintesi vocale che pronuncia il nome del bidone in cui gettare il rifiuto.
# ![immagine-3.png](attachment:immagine-3.png)
